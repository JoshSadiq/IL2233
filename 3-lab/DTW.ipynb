# %% [markdown]
# # Task 3: Dynamic Time Warping

# %% [markdown]
# ### Imports

# %%
import numpy as np

# %% [markdown]
# ### Data loading

# %%
x = np.array([1, 2, 3, 2, 1])
y = np.array([1, 1, 3, 4, 3, 1, 1])

# %% [markdown]
# ### Function definitions

# %%
# Takes two time series x and y as inputs and returns new array with euclidean distance of the two
# If one time series is longer than the other, will only compute the distance for len(smaller time series)
def eu_distance(x, y):
    eu_dist = np.array([])

    if len(x) < len(y):
        for i in range(0, len(x)):
            eu_dist = np.append(eu_dist, abs(x[i]-y[i]))
    else:
        for i in range(0, len(y)):
            eu_dist = np.append(eu_dist, abs(x[i]-y[i]))

    return eu_dist

# Takes two time series x and y as inputs and returns new array with DTW distance of the two
def dtw_distance(x, y):
    dtw_dist = np.array([])

# %% [markdown]
# ### Give a hand-calculation of the Euclidean distance: eu distance(x,y) and the DTW distance: dtw distance(x,y)

# %%
eu_dist = eu_distance(x, y)
print("Euclidean distances between series x and y are:", eu_dist)
# Out:
# Euclidean distances between series x and y are: [0 1 0 2 2]

# %%
import numpy as np
import matplotlib.pyplot as plt

# Set the parameters
frequency = 20  # Frequency in Hz
data_points = 25  # Number of data points
x1 = np.linspace(1, 10, data_points)  # x-values ranging from 1 to 10

# Calculate the y-values (sinusoidal wave)
y1 = np.sin(2 * np.pi * frequency * x1)



# Set the parameters
frequency = 25  # Frequency in Hz
data_points = 25  # Number of data points
x2 = np.linspace(1, 10, data_points)  # x-values ranging from 1 to 10

# Calculate the y-values (sinusoidal wave)
y2 = np.sin(2 * np.pi * frequency * x2)

# Plot the sinusoidal wave
plt.plot(x1, y1)
plt.plot(x2, y2)

plt.xlabel('Time')
plt.ylabel('Amplitude')
plt.title('Sinusoidal Wave with Frequency 10 Hz')
plt.show()

print(y)
# Out:
# [-1.95943488e-15 -9.84807753e-01 -3.42020143e-01  8.66025404e-01
#   6.42787610e-01 -6.42787610e-01 -8.66025404e-01  3.42020143e-01
#   9.84807753e-01 -5.87830464e-15]
